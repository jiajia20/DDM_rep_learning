# %% [markdown]
# ## Goal
# This is to test the effectiveness of the new code and specifically to find out:
# 1 - if the

# %%
import study_annotated_small as sas
import seaborn as sns

# %%
sas.main()
# Out:
# 100%|██████████| 300/300 [00:12<00:00, 23.36it/s]

# %% [markdown]
# ## Visualization

# %%
import pandas
csv = pandas.read_csv('s-log-2022-03-17.csv', sep=',', header=0)
df_fully_connected = csv[csv['network'] == 'fully-connected']
df_disconnected = csv[csv['network'] == 'disconnected']
df_ring = csv[csv['network'] == 'ring']

# %%
# check how many rounds
len(df_fully_connected.loc[df_fully_connected['round'] == 0])
# Out:
# 300

# %% [markdown]
# ### test

# %%
df_ring

# %%
df_fully_connected['1-2-choice'] = df_fully_connected['player 1 choice'].astype(str) + df_fully_connected['player 2 choice'].astype(str)
df_fully_connected

# %%
df_fully_connected_r = df_fully_connected[["participant cluster", "round","1-2-choice"]]
df_fully_connected_r

# %%
participant_round_counts = df_fully_connected_r.groupby(['1-2-choice','round']).count().reset_index()
participant_round_counts

# %%
pvt = pandas.pivot_table(participant_round_counts, values='participant cluster', index='round',columns=['1-2-choice'])/30

# %%
pvt

# %% [markdown]
# ### Fully connected

# %%
df_fully_connected['1-2-rep'] = df_fully_connected['player 1 rep'].astype(str) + df_fully_connected['player 2 rep'].astype(str)
df_fully_connected_r = df_fully_connected[["participant cluster", "round","1-2-rep"]]

participant_round_counts = df_fully_connected_r.groupby(['1-2-rep','round']).count().reset_index()
#participant_round_counts.rename(colums={'1-2-choice': 'choice of agent A and B'}, inplace=True)

pvt = pandas.pivot_table(participant_round_counts, values='participant cluster', index='round',columns=['1-2-rep'])/300
sns.lineplot(data=pvt).set(title='Fully Connected Rep',ylim=(0, 1.2))
# Out:
# /Users/cmu-work/opt/anaconda3/envs/DDML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [Text(0.5, 1.0, 'Fully Connected Rep'), (0.0, 1.2)]

# %%
df_fully_connected['1-2-choice'] = df_fully_connected['player 1 choice'].astype(str) + df_fully_connected['player 2 choice'].astype(str)
df_fully_connected_r = df_fully_connected[["participant cluster", "round","1-2-choice"]]
participant_round_counts = df_fully_connected_r.groupby(['1-2-choice','round']).count().reset_index()
#participant_round_counts.rename(colums={'1-2-choice': 'choice of agent A and B'}, inplace=True)

pvt = pandas.pivot_table(participant_round_counts, values='participant cluster', index='round',columns=['1-2-choice'])/300
sns.lineplot(data=pvt).set(title='Fully connected',ylim=(0, 1))
# Out:
# /Users/cmu-work/opt/anaconda3/envs/DDML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [Text(0.5, 1.0, 'Fully connected'), (0.0, 1.0)]

# %% [markdown]
# ### ring

# %%
df_ring['1-2-rep'] = df_ring['player 1 rep'].astype(str) + df_ring['player 2 rep'].astype(str)
df_ring_r = df_ring[["participant cluster", "round","1-2-rep"]]

participant_round_counts = df_ring_r.groupby(['1-2-rep','round']).count().reset_index()
#participant_round_counts.rename(colums={'1-2-choice': 'choice of agent A and B'}, inplace=True)

pvt = pandas.pivot_table(participant_round_counts, values='participant cluster', index='round',columns=['1-2-rep'])/300
sns.lineplot(data=pvt).set(title='Ring Rep',ylim=(0, 1.2))
# Out:
# /Users/cmu-work/opt/anaconda3/envs/DDML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [Text(0.5, 1.0, 'Ring Rep'), (0.0, 1.2)]

# %%
df_ring['1-2-choice'] = df_ring['player 1 choice'].astype(str) + df_ring['player 2 choice'].astype(str)
df_ring_r = df_ring[["participant cluster", "round","1-2-choice"]]

participant_round_counts = df_ring_r.groupby(['1-2-choice','round']).count().reset_index()
#participant_round_counts.rename(colums={'1-2-choice': 'choice of agent A and B'}, inplace=True)

pvt = pandas.pivot_table(participant_round_counts, values='participant cluster', index='round',columns=['1-2-choice'])/300
sns.lineplot(data=pvt).set(title='Ring',ylim=(0, 1))
# Out:
# /Users/cmu-work/opt/anaconda3/envs/DDML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [Text(0.5, 1.0, 'Ring'), (0.0, 1.0)]

# %% [markdown]
# ### Disconnected

# %%
df_disconnected['1-2-rep'] = df_disconnected['player 1 rep'].astype(str) + df_disconnected['player 2 rep'].astype(str)
df_disconnected_r = df_disconnected[["participant cluster", "round","1-2-rep"]]

participant_round_counts = df_disconnected_r.groupby(['1-2-rep','round']).count().reset_index()
#participant_round_counts.rename(colums={'1-2-choice': 'choice of agent A and B'}, inplace=True)

pvt = pandas.pivot_table(participant_round_counts, values='participant cluster', index='round',columns=['1-2-rep'])/300
sns.lineplot(data=pvt).set(title='Disconnected Rep',ylim=(0, 1.2))
# Out:
# /Users/cmu-work/opt/anaconda3/envs/DDML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [Text(0.5, 1.0, 'Disconnected Rep'), (0.0, 1.2)]

# %%
df_disconnected['1-2-choice'] = df_disconnected['player 1 choice'].astype(str) + df_disconnected['player 2 choice'].astype(str)
df_disconnected_r = df_disconnected[["participant cluster", "round","1-2-choice"]]

participant_round_counts = df_disconnected_r.groupby(['1-2-choice','round']).count().reset_index()
#participant_round_counts.rename(colums={'1-2-choice': 'choice of agent A and B'}, inplace=True)

pvt = pandas.pivot_table(participant_round_counts, values='participant cluster', index='round',columns=['1-2-choice'])/300
sns.lineplot(data=pvt).set(title='Disconnected',ylim=(0, 1))
# Out:
# /Users/cmu-work/opt/anaconda3/envs/DDML/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# [Text(0.5, 1.0, 'Disconnected'), (0.0, 1.0)]
